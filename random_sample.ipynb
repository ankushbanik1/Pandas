# %%
import pandas as pd

df=pd.read_csv("pokemon.csv")

df.set_index("Name",inplace=True)
df.head()
# Out:
#                # Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Name
# Bulbasaur      1  Grass  Poison  45      49       49       65       65     45
# Ivysaur        2  Grass  Poison  60      62       63       80       80     60
# Venusaur       3  Grass  Poison  80      82       83      100      100     80
# Mega Venusaur  4  Grass  Poison  80     100      123      122      120     80
# Charmander     5   Fire     NaN  39      52       43       60       50     65
#
#                Generation  Legendary
# Name
# Bulbasaur               1      False
# Ivysaur                 1      False
# Venusaur                1      False
# Mega Venusaur           1      False
# Charmander              1      False

# %%
df.sample(frac=.45)
df.sample(n=4,axis=1)
# Out:
#                         Legendary  Sp. Def   HP  Type 2
# Name
# Bulbasaur                   False       65   45  Poison
# Ivysaur                     False       80   60  Poison
# Venusaur                    False      100   80  Poison
# Mega Venusaur               False      120   80  Poison
# Charmander                  False       50   39     NaN
# Charmeleon                  False       65   58     NaN
# Charizard                   False       85   78  Flying
# Mega Charizard X            False       85   78  Dragon
# Mega Charizard Y            False      115   78  Flying
# Squirtle                    False       64   44     NaN
# Wartortle                   False       80   59     NaN
# Blastoise                   False      105   79     NaN
# Mega Blastoise              False      115   79     NaN
# Caterpie                    False       20   45     NaN
# Metapod                     False       25   50     NaN
# Butterfree                  False       80   60  Flying
# ...
