# %%
import pandas as pd

df=pd.read_csv("pokemon.csv")
df.sort_values("Name",inplace=True)
df.head()
df["ankush"]="100"
df.insert(4,column="ankkush",value=158)
df.head()
# Out:
#        #                   Name   Type 1 Type 2  ankkush  HP  Attack  Defense  \
# 510  511              Abomasnow    Grass    Ice      158  90      92       75
# 68    69                   Abra  Psychic    NaN      158  25      20       15
# 392  393                  Absol     Dark    NaN      158  65     130       60
# 678  679               Accelgor      Bug    NaN      158  80      70       40
# 750  751  Aegislash Blade Forme    Steel  Ghost      158  60     150       50
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary ankush
# 510       92       85     60           4      False    100
# 68       105       55     90           1      False    100
# 392       75       60     75           3      False    100
# 678      100       60    145           5      False    100
# 750      150       50     60           6      False    100

# %%
df.set_index("Name")
# Out:
#                           #    Type 1    Type 2  ankkush   HP  Attack  \
# Name
# Abomasnow               511     Grass       Ice      158   90      92
# Abra                     69   Psychic       NaN      158   25      20
# Absol                   393      Dark       NaN      158   65     130
# Accelgor                679       Bug       NaN      158   80      70
# Aegislash Blade Forme   751     Steel     Ghost      158   60     150
# Aegislash Shield Forme  752     Steel     Ghost      158   60      50
# Aerodactyl              154      Rock    Flying      158   80     105
# Aggron                  333     Steel      Rock      158   70     110
# Aipom                   206    Normal       NaN      158   55      70
# Alakazam                 71   Psychic       NaN      158   55      50
# Alomomola               656     Water       NaN      158  165      75
# Altaria                 366    Dragon    Flying      158   75      70
# ...

# %%
df.reset_index()
df.head()
# Out:
#        #                   Name   Type 1 Type 2  ankkush  HP  Attack  Defense  \
# 510  511              Abomasnow    Grass    Ice      158  90      92       75
# 68    69                   Abra  Psychic    NaN      158  25      20       15
# 392  393                  Absol     Dark    NaN      158  65     130       60
# 678  679               Accelgor      Bug    NaN      158  80      70       40
# 750  751  Aegislash Blade Forme    Steel  Ghost      158  60     150       50
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary ankush
# 510       92       85     60           4      False    100
# 68       105       55     90           1      False    100
# 392       75       60     75           3      False    100
# 678      100       60    145           5      False    100
# 750      150       50     60           6      False    100

# %%
df.nlargest(3,"Defense")
# Out:
#        #          Name Type 1  Type 2  ankkush  HP  Attack  Defense  Sp. Atk  \
# 333  334   Mega Aggron  Steel     NaN      158  70     140      230       60
# 224  225  Mega Steelix  Steel  Ground      158  75     125      230       55
# 230  231       Shuckle    Bug    Rock      158  20      10      230       10
#
#      Sp. Def  Speed  Generation  Legendary ankush
# 333       80     50           3      False    100
# 224       95     30           2      False    100
# 230      230      5           2      False    100

# %%
df.nsmallest(5,"Defense")
# Out:
#        #       Name   Type 1 Type 2  ankkush   HP  Attack  Defense  Sp. Atk  \
# 121  122    Chansey   Normal    NaN      158  250       5        5       35
# 488  489    Happiny   Normal    NaN      158  100       5        5       15
# 261  262    Blissey   Normal    NaN      158  255      10       10       75
# 68    69       Abra  Psychic    NaN      158   25      20       15      105
# 188  189  Igglybuff   Normal  Fairy      158   90      30       15       40
#
#      Sp. Def  Speed  Generation  Legendary ankush
# 121      105     50           1      False    100
# 488       65     30           4      False    100
# 261      135     55           2      False    100
# 68        55     90           1      False    100
# 188       20     15           2      False    100

# %%
import pandas as pd

df=pd.read_csv("pokemon.csv")
df.sort_values("Name",inplace=True)
df.head()

del df["Name"]
df
# Out:
#        #    Type 1    Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 510  511     Grass       Ice   90      92       75       92       85     60
# 68    69   Psychic       NaN   25      20       15      105       55     90
# 392  393      Dark       NaN   65     130       60       75       60     75
# 678  679       Bug       NaN   80      70       40      100       60    145
# 750  751     Steel     Ghost   60     150       50      150       50     60
# 751  752     Steel     Ghost   60      50      150       50      150     60
# 153  154      Rock    Flying   80     105       65       60       75    130
# 332  333     Steel      Rock   70     110      180       60       60     50
# 205  206    Normal       NaN   55      70       55       40       55     85
# 70    71   Psychic       NaN   55      50       45      135       95    120
# 655  656     Water       NaN  165      75       80       40       45     65
# ...

# %%
import pandas as pd

df=pd.read_csv("pokemon.csv")
df.sort_values("Name",inplace=True)
df.set_index("Name",inplace=True)
df.head()
# Out:
#                          #   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# Name
# Abomasnow              511    Grass    Ice  90      92       75       92
# Abra                    69  Psychic    NaN  25      20       15      105
# Absol                  393     Dark    NaN  65     130       60       75
# Accelgor               679      Bug    NaN  80      70       40      100
# Aegislash Blade Forme  751    Steel  Ghost  60     150       50      150
#
#                        Sp. Def  Speed  Generation  Legendary
# Name
# Abomasnow                   85     60           4      False
# Abra                        55     90           1      False
# Absol                       60     75           3      False
# Accelgor                    60    145           5      False
# Aegislash Blade Forme       50     60           6      False

# %%
df.ix["Absol","Type 1"]=="454"
df.ix["Absol"]
# Out:
# C:\Users\ankush\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# C:\Users\ankush\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
# #               393
# Type 1         Dark
# Type 2          NaN
# HP               65
# Attack          130
# Defense          60
# Sp. Atk          75
# Sp. Def          60
# Speed            75
# Generation        3
# Legendary     False
# Name: Absol, dtype: object

# %%
mask=df["HP"]<45
mask1=df["Type 1"]=="Grass"
df[mask & mask1]
# Out:
#              # Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Name
# Budew      452  Grass  Poison  40      30       35       50       70     55
# Cottonee   607  Grass   Fairy  40      27       60       37       50     66
# Ferroseed  659  Grass   Steel  44      50       91       24       86     10
# Hoppip     203  Grass  Flying  35      35       40       35       55     50
# Seedot     297  Grass     NaN  40      40       50       30       30     30
# Sunkern    207  Grass     NaN  30      30       30       30       30     30
# Treecko    273  Grass     NaN  40      45       35       65       55     70
#
#            Generation  Legendary
# Name
# Budew               4      False
# Cottonee            5      False
# Ferroseed           5      False
# Hoppip              2      False
# Seedot              3      False
# Sunkern             2      False
# Treecko             3      False

# %%
mas=df["HP"].between(12,56)
df[mas]
# Out:
#               #    Type 1   Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Name
# Abra         69   Psychic      NaN  25      20       15      105       55
# Aipom       206    Normal      NaN  55      70       55       40       55
# Alakazam     71   Psychic      NaN  55      50       45      135       95
# Anorith     380      Rock      Bug  45      95       50       40       50
# Archen      628      Rock   Flying  55     112       45       74       45
# Aron        331     Steel     Rock  50      70      100       40       40
# Axew        672    Dragon      NaN  46      87       60       30       40
# Azurill     323    Normal    Fairy  50      20       40       20       40
# Bagon       407    Dragon      NaN  45      75       60       40       30
# Baltoy      376    Ground  Psychic  40      40       55       40       70
# Barboach    372     Water   Ground  50      48       43       46       41
# Beldum      411     Steel  Psychic  40      55       80       35       60
# ...

# %%
df["HP"]=df["HP"]+4
df
# Out:
#                           #    Type 1    Type 2   HP  Attack  Defense  \
# Name
# Abomasnow               511     Grass       Ice   94      92       75
# Abra                     69   Psychic       NaN   29      20       15
# Absol                   393      Dark       NaN   69     130       60
# Accelgor                679       Bug       NaN   84      70       40
# Aegislash Blade Forme   751     Steel     Ghost   64     150       50
# Aegislash Shield Forme  752     Steel     Ghost   64      50      150
# Aerodactyl              154      Rock    Flying   84     105       65
# Aggron                  333     Steel      Rock   74     110      180
# Aipom                   206    Normal       NaN   59      70       55
# Alakazam                 71   Psychic       NaN   59      50       45
# Alomomola               656     Water       NaN  169      75       80
# Altaria                 366    Dragon    Flying   79      70       90
# ...

# %%
df["Type 2"]=df["Type 2"].fillna(99)
df
# Out:
#                           #    Type 1    Type 2   HP  Attack  Defense  \
# Name
# Abomasnow               511     Grass       Ice   94      92       75
# Abra                     69   Psychic        99   29      20       15
# Absol                   393      Dark        99   69     130       60
# Accelgor                679       Bug        99   84      70       40
# Aegislash Blade Forme   751     Steel     Ghost   64     150       50
# Aegislash Shield Forme  752     Steel     Ghost   64      50      150
# Aerodactyl              154      Rock    Flying   84     105       65
# Aggron                  333     Steel      Rock   74     110      180
# Aipom                   206    Normal        99   59      70       55
# Alakazam                 71   Psychic        99   59      50       45
# Alomomola               656     Water        99  169      75       80
# Altaria                 366    Dragon    Flying   79      70       90
# ...

# %%
df.drop_duplicates(subset="Type 2",keep="first")
# Out:
#                          #    Type 1    Type 2   HP  Attack  Defense  Sp. Atk  \
# Name
# Abomasnow              511     Grass       Ice   94      92       75       92
# Abra                    69   Psychic        99   29      20       15      105
# Aegislash Blade Forme  751     Steel     Ghost   64     150       50      150
# Aerodactyl             154      Rock    Flying   84     105       65       60
# Aggron                 333     Steel      Rock   74     110      180       60
# Amoonguss              653     Grass    Poison  118      85       70       85
# Anorith                380      Rock       Bug   49      95       50       40
# Azumarill              200     Water     Fairy  104      50       80       60
# Baltoy                 376    Ground   Psychic   44      40       55       40
# Barbaracle             760      Rock     Water   76     105      115       54
# Barboach               372     Water    Ground   54      48       43       46
# ...

# %%
df.columns=[colum.replace(" ","_")for colum in df.colums]
df.head()
df.query('Type_2=="Poison"')
# Out:
#                  # Type_1  Type_2   HP  Attack  Defense  Sp._Atk  Sp._Def  \
# Name
# Amoonguss      653  Grass  Poison  118      85       70       85       80
# Ariados        183    Bug  Poison   74      90       70       60       60
# Beedrill        19    Bug  Poison   69      90       40       45       80
# Bellsprout      76  Grass  Poison   54      75       35       70       30
# Budew          452  Grass  Poison   44      30       35       50       70
# Bulbasaur        1  Grass  Poison   49      49       49       65       65
# Dustox         293    Bug  Poison   64      50       70       50       90
# Foongus        652  Grass  Poison   73      55       45       55       55
# Gastly         100  Ghost  Poison   34      35       30      100       35
# Gengar         102  Ghost  Poison   64      65       60      130       75
# Gloom           50  Grass  Poison   64      65       70       85       75
# Haunter        101  Ghost  Poison   49      50       45      115       55
# ...
