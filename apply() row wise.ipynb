# %%
import pandas as pd

df=pd.read_csv("pokemon.csv",index_col="Name")
df.head()

   
df.columns=[col_name.replace(" ","_")for col_name in df.columns]   
df.head()
# Out:
#                # Type_1  Type_2  HP  Attack  Defense  Sp._Atk  Sp._Def  Speed  \
# Name
# Bulbasaur      1  Grass  Poison  45      49       49       65       65     45
# Ivysaur        2  Grass  Poison  60      62       63       80       80     60
# Venusaur       3  Grass  Poison  80      82       83      100      100     80
# Mega Venusaur  4  Grass  Poison  80     100      123      122      120     80
# Charmander     5   Fire     NaN  39      52       43       60       50     65
#
#                Generation  Legendary
# Name
# Bulbasaur               1      False
# Ivysaur                 1      False
# Venusaur                1      False
# Mega Venusaur           1      False
# Charmander              1      False

# %%
def ank(row):
    Type_1=row[2]
    HP=row[4]
    
    if Type_1=="Grass":
        return "hello i am good "
    
    elif Type_1 =="Fire" and HP >47:
        
        
        return "ohh fuck "
    else:
        return "ohh yahhhh"
    
[df.apply(ank,axis="columns")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-e7e2fec7b301> in <module>
#      13         return "ohh yahhhh"
#      14
# ---> 15 df[df.apply(ank,axis="columns") ]
#
# c:\users\ankush\appdata\local\programs\python\python37\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2932                 key = list(key)
#    2933             indexer = self.loc._convert_to_indexer(key, axis=1,
# -> 2934                                                    raise_missing=True)
#    2935
#    2936         # take() does not accept boolean indexers
#
# c:\users\ankush\appdata\local\programs\python\python37\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1352                 kwargs = {'raise_missing': True if is_setter else
#    1353                           raise_missing}
# ...
