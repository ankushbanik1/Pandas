# %%
import pandas as pd

df=pd.read_csv("pokemon.csv")

df.set_index("Name",inplace=True)
df.head()
# Out:
#                # Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Name
# Bulbasaur      1  Grass  Poison  45      49       49       65       65     45
# Ivysaur        2  Grass  Poison  60      62       63       80       80     60
# Venusaur       3  Grass  Poison  80      82       83      100      100     80
# Mega Venusaur  4  Grass  Poison  80     100      123      122      120     80
# Charmander     5   Fire     NaN  39      52       43       60       50     65
#
#                Generation  Legendary
# Name
# Bulbasaur               1      False
# Ivysaur                 1      False
# Venusaur                1      False
# Mega Venusaur           1      False
# Charmander              1      False

# %%
def app(number):
    return str(number)+" loude"

df["Type 1"]=df["Type 1"].apply(app)
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e261656b1147> in <module>
#       2     return str(number)+" loude"
#       3
# ----> 4 df["Type 1"]=df["Type 1"].apply(app)
#       5 df.head()
#
# NameError: name 'df' is not defined

# %%
df.nsmallest(1,"Attack")
# Out:
#            #        Type 1 Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Name
# Chansey  122  Normal loude    NaN  250       5        5       35      105
#
#          Speed  Generation  Legendary
# Name
# Chansey     50           1      False

# %%
def comp(n):
    if n>45:
        return n
    else:
        return print("hello")
    
    
df["Attack"]=df["Attack"].apply(comp)
df.head()
# Out:
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# ...
