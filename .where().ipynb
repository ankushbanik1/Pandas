# %%
import pandas as pd

df=pd.read_csv("pokemon.csv")

df.set_index("Name",inplace=True)
df.head()
# Out:
#                # Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Name
# Bulbasaur      1  Grass  Poison  45      49       49       65       65     45
# Ivysaur        2  Grass  Poison  60      62       63       80       80     60
# Venusaur       3  Grass  Poison  80      82       83      100      100     80
# Mega Venusaur  4  Grass  Poison  80     100      123      122      120     80
# Charmander     5   Fire     NaN  39      52       43       60       50     65
#
#                Generation  Legendary
# Name
# Bulbasaur               1      False
# Ivysaur                 1      False
# Venusaur                1      False
# Mega Venusaur           1      False
# Charmander              1      False

# %%
mask2=df['Type 2']=="Poison"
# Out:
#                            # Type 1  Type 2    HP  Attack  Defense  Sp. Atk  \
# Name
# Bulbasaur                1.0  Grass  Poison  45.0    49.0     49.0     65.0
# Ivysaur                  2.0  Grass  Poison  60.0    62.0     63.0     80.0
# Venusaur                 3.0  Grass  Poison  80.0    82.0     83.0    100.0
# Mega Venusaur            4.0  Grass  Poison  80.0   100.0    123.0    122.0
# Charmander               NaN    NaN     NaN   NaN     NaN      NaN      NaN
# Charmeleon               NaN    NaN     NaN   NaN     NaN      NaN      NaN
# Charizard                NaN    NaN     NaN   NaN     NaN      NaN      NaN
# Mega Charizard X         NaN    NaN     NaN   NaN     NaN      NaN      NaN
# Mega Charizard Y         NaN    NaN     NaN   NaN     NaN      NaN      NaN
# Squirtle                 NaN    NaN     NaN   NaN     NaN      NaN      NaN
# Wartortle                NaN    NaN     NaN   NaN     NaN      NaN      NaN
# ...

# %%
mask2=df['Speed']>100
df.where(mask & mask2)
# Out:
#                             #    Type 1  Type 2    HP  Attack  Defense  \
# Name
# Bulbasaur                 NaN       NaN     NaN   NaN     NaN      NaN
# Ivysaur                   NaN       NaN     NaN   NaN     NaN      NaN
# Venusaur                  NaN       NaN     NaN   NaN     NaN      NaN
# Mega Venusaur             NaN       NaN     NaN   NaN     NaN      NaN
# Charmander                NaN       NaN     NaN   NaN     NaN      NaN
# Charmeleon                NaN       NaN     NaN   NaN     NaN      NaN
# Charizard                 NaN       NaN     NaN   NaN     NaN      NaN
# Mega Charizard X          NaN       NaN     NaN   NaN     NaN      NaN
# Mega Charizard Y          NaN       NaN     NaN   NaN     NaN      NaN
# Squirtle                  NaN       NaN     NaN   NaN     NaN      NaN
# Wartortle                 NaN       NaN     NaN   NaN     NaN      NaN
# Blastoise                 NaN       NaN     NaN   NaN     NaN      NaN
# ...
