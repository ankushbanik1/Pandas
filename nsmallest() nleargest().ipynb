# %%
import pandas as pd

df=pd.read_csv("pokemon.csv")

df.set_index("Name",inplace=True)
df.head()
# Out:
#                # Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Name
# Bulbasaur      1  Grass  Poison  45      49       49       65       65     45
# Ivysaur        2  Grass  Poison  60      62       63       80       80     60
# Venusaur       3  Grass  Poison  80      82       83      100      100     80
# Mega Venusaur  4  Grass  Poison  80     100      123      122      120     80
# Charmander     5   Fire     NaN  39      52       43       60       50     65
#
#                Generation  Legendary
# Name
# Bulbasaur               1      False
# Ivysaur                 1      False
# Venusaur                1      False
# Mega Venusaur           1      False
# Charmander              1      False

# %%
df.nsmallest(2,"HP")
# Out:
#             #  Type 1 Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Name
# Shedinja  317     Bug  Ghost   1      90       45       30       30     40
# Diglett    56  Ground    NaN  10      55       25       35       45     95
#
#           Generation  Legendary
# Name
# Shedinja           3      False
# Diglett            1      False

# %%
df.nlargest(2,"HP")
# Out:
#            #  Type 1 Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Name
# Blissey  262  Normal    NaN  255      10       10       75      135     55
# Chansey  122  Normal    NaN  250       5        5       35      105     50
#
#          Generation  Legendary
# Name
# Blissey           2      False
# Chansey           1      False

# %%
df["HP"].nlargest(3)
# Out:
# Name
# Blissey      255
# Chansey      250
# Wobbuffet    190
# Name: HP, dtype: int64
