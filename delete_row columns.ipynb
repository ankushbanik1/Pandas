# %%
import pandas as pd

df=pd.read_csv("pokemon.csv")

df.set_index("Name",inplace=True)
df.head()
# Out:
#                # Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Name
# Bulbasaur      1  Grass  Poison  45      49       49       65       65     45
# Ivysaur        2  Grass  Poison  60      62       63       80       80     60
# Venusaur       3  Grass  Poison  80      82       83      100      100     80
# Mega Venusaur  4  Grass  Poison  80     100      123      122      120     80
# Charmander     5   Fire     NaN  39      52       43       60       50     65
#
#                Generation  Legendary
# Name
# Bulbasaur               1      False
# Ivysaur                 1      False
# Venusaur                1      False
# Mega Venusaur           1      False
# Charmander              1      False

# %%
df.drop("Venusaur")
df.drop(["Venusaur","Mega Venusaur"])
df.drop(["Type 1","Type 2"],axis=1,inplace=True)
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-13c4b8a02e7a> in <module>
#       1 df.drop("Venusaur")
#       2 df.drop(["Venusaur","Mega Venusaur"])
# ----> 3 df.drop(["Type 1","Type 2"],axis=1,inplace=True)
#       4 df.head()
#
# c:\users\ankush\appdata\local\programs\python\python37\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3938                                            index=index, columns=columns,
#    3939                                            level=level, inplace=inplace,
# -> 3940                                            errors=errors)
#    3941
#    3942     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ...

# %%
import pandas as pd

df=pd.read_csv("pokemon.csv")

df.set_index("Name",inplace=True)
df.head()
# Out:
#                # Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Name
# Bulbasaur      1  Grass  Poison  45      49       49       65       65     45
# Ivysaur        2  Grass  Poison  60      62       63       80       80     60
# Venusaur       3  Grass  Poison  80      82       83      100      100     80
# Mega Venusaur  4  Grass  Poison  80     100      123      122      120     80
# Charmander     5   Fire     NaN  39      52       43       60       50     65
#
#                Generation  Legendary
# Name
# Bulbasaur               1      False
# Ivysaur                 1      False
# Venusaur                1      False
# Mega Venusaur           1      False
# Charmander              1      False

# %%
ac=df.pop("Attack")
ac
# Out:
# Name
# Bulbasaur                  49
# Ivysaur                    62
# Venusaur                   82
# Mega Venusaur             100
# Charmander                 52
# Charmeleon                 64
# Charizard                  84
# Mega Charizard X          130
# Mega Charizard Y          104
# Squirtle                   48
# Wartortle                  63
# Blastoise                  83
# Mega Blastoise            103
# Caterpie                   30
# Metapod                    20
# Butterfree                 45
# Weedle                     35
# Kakuna                     25
# Beedrill                   90
# Mega Beedrill             150
# Pidgey                     45
# Pidgeotto                  60
# Pidgeot                    80
# Mega Pidgeot               80
# Rattata                    56
# Raticate                   81
# Spearow                    60
# Fearow                     90
# Ekans                      60
# Arbok                      85
#                          ...
# ...

# %%
del df["HP"]
df
# Out:
#                           #    Type 1  Type 2  Attack  Defense  Sp. Atk  \
# Name
# Bulbasaur                 1     Grass  Poison      49       49       65
# Ivysaur                   2     Grass  Poison      62       63       80
# Venusaur                  3     Grass  Poison      82       83      100
# Mega Venusaur             4     Grass  Poison     100      123      122
# Charmander                5      Fire     NaN      52       43       60
# Charmeleon                6      Fire     NaN      64       58       80
# Charizard                 7      Fire  Flying      84       78      109
# Mega Charizard X          8      Fire  Dragon     130      111      130
# Mega Charizard Y          9      Fire  Flying     104       78      159
# Squirtle                 10     Water     NaN      48       65       50
# Wartortle                11     Water     NaN      63       80       65
# Blastoise                12     Water     NaN      83      100       85
# ...
