# %%
import pandas as pd

df=pd.read_csv("pokemon.csv")

df.set_index("Name",inplace=True)
df.head()
# Out:
#                # Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Name
# Bulbasaur      1  Grass  Poison  45      49       49       65       65     45
# Ivysaur        2  Grass  Poison  60      62       63       80       80     60
# Venusaur       3  Grass  Poison  80      82       83      100      100     80
# Mega Venusaur  4  Grass  Poison  80     100      123      122      120     80
# Charmander     5   Fire     NaN  39      52       43       60       50     65
#
#                Generation  Legendary
# Name
# Bulbasaur               1      False
# Ivysaur                 1      False
# Venusaur                1      False
# Mega Venusaur           1      False
# Charmander              1      False

# %%
import pandas as pd

df=pd.read_csv("pokemon.csv")

df.set_index("Name",inplace=True)
df.head()

# %%
import pandas as pd

df=pd.read_csv("pokemon.csv")

df.set_index("Name",inplace=True)
df.head()
# Out:
#                # Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Name
# Bulbasaur      1  Grass  Poison  45      49       49       65       65     45
# Ivysaur        2  Grass  Poison  60      62       63       80       80     60
# Venusaur       3  Grass  Poison  80      82       83      100      100     80
# Mega Venusaur  4  Grass  Poison  80     100      123      122      120     80
# Charmander     5   Fire     NaN  39      52       43       60       50     65
#
#                Generation  Legendary
# Name
# Bulbasaur               1      False
# Ivysaur                 1      False
# Venusaur                1      False
# Mega Venusaur           1      False
# Charmander              1      False

# %%
 df.columns=[ colums.replace(" ","_") for colums in df.columns]
df.head()
# Out:
#                # Type_1  Type_2  HP  Attack  Defense  Sp._Atk  Sp._Def  Speed  \
# Name
# Bulbasaur      1  Grass  Poison  45      49       49       65       65     45
# Ivysaur        2  Grass  Poison  60      62       63       80       80     60
# Venusaur       3  Grass  Poison  80      82       83      100      100     80
# Mega Venusaur  4  Grass  Poison  80     100      123      122      120     80
# Charmander     5   Fire     NaN  39      52       43       60       50     65
#
#                Generation  Legendary
# Name
# Bulbasaur               1      False
# Ivysaur                 1      False
# Venusaur                1      False
# Mega Venusaur           1      False
# Charmander              1      False

# %%
i=df.columns=[columns_name.replace("p","") for columns_name in df.columns ]
df.head()
# Out:
#                # Ty    e_1 Ty    e_2  HP  Attack  Defense  S    ._Atk  \
# Name
# Bulbasaur      1     Grass    Poison  45      49       49          65
# Ivysaur        2     Grass    Poison  60      62       63          80
# Venusaur       3     Grass    Poison  80      82       83         100
# Mega Venusaur  4     Grass    Poison  80     100      123         122
# Charmander     5      Fire       NaN  39      52       43          60
#
#                S    ._Def  S    eed  Generation  Legendary
# Name
# Bulbasaur              65        45           1      False
# Ivysaur                80        60           1      False
# Venusaur              100        80           1      False
# Mega Venusaur         120        80           1      False
# Charmander             50        65           1      False

# %%
df.columns=[columns_name.replace(" ","p") for columns_name in df.columns ]
df.head()
# Out:
#                # Typpppe_1 Typpppe_2  HP  Attack  Defense  Spppp._Atk  \
# Name
# Bulbasaur      1     Grass    Poison  45      49       49          65
# Ivysaur        2     Grass    Poison  60      62       63          80
# Venusaur       3     Grass    Poison  80      82       83         100
# Mega Venusaur  4     Grass    Poison  80     100      123         122
# Charmander     5      Fire       NaN  39      52       43          60
#
#                Spppp._Def  Sppppeed  Generation  Legendary
# Name
# Bulbasaur              65        45           1      False
# Ivysaur                80        60           1      False
# Venusaur              100        80           1      False
# Mega Venusaur         120        80           1      False
# Charmander             50        65           1      False

# %%
df.columns=[columns_name.replace("ppp","") for columns_name in df.columns ]

df.query('Type_2=="Poison"')
# Out:
#                  # Type_1  Type_2   HP  Attack  Defense  Sp._Atk  Sp._Def  \
# Name
# Bulbasaur        1  Grass  Poison   45      49       49       65       65
# Ivysaur          2  Grass  Poison   60      62       63       80       80
# Venusaur         3  Grass  Poison   80      82       83      100      100
# Mega Venusaur    4  Grass  Poison   80     100      123      122      120
# Weedle          17    Bug  Poison   40      35       30       20       20
# Kakuna          18    Bug  Poison   45      25       50       25       25
# Beedrill        19    Bug  Poison   65      90       40       45       80
# Mega Beedrill   20    Bug  Poison   65     150       40       15       80
# Oddish          49  Grass  Poison   45      50       55       75       65
# Gloom           50  Grass  Poison   60      65       70       85       75
# Vileplume       51  Grass  Poison   75      80       85      110       90
# Venonat         54    Bug  Poison   60      55       50       40       55
# ...

# %%
df.query('Type_2!="Poison"')
# Out:
#                           #    Type_1  Type_2   HP  Attack  Defense  Sp._Atk  \
# Name
# Charmander                5      Fire     NaN   39      52       43       60
# Charmeleon                6      Fire     NaN   58      64       58       80
# Charizard                 7      Fire  Flying   78      84       78      109
# Mega Charizard X          8      Fire  Dragon   78     130      111      130
# Mega Charizard Y          9      Fire  Flying   78     104       78      159
# Squirtle                 10     Water     NaN   44      48       65       50
# Wartortle                11     Water     NaN   59      63       80       65
# Blastoise                12     Water     NaN   79      83      100       85
# Mega Blastoise           13     Water     NaN   79     103      120      135
# Caterpie                 14       Bug     NaN   45      30       35       20
# Metapod                  15       Bug     NaN   50      20       55       25
# ...

# %%
df.query("Type_2=='Psychic' and Type_1== 'Water'" )
# Out:
# Empty DataFrame
# Columns: [#, Type_1, Type_2, HP, Attack, Defense, Sp._Atk, Sp._Def, Speed, Generation, Legendary]
# Index: []

# %%
df.query("Type_2 not in ['Dark','Ghost']")
# Out:
#                           #    Type_1  Type_2   HP  Attack  Defense  Sp._Atk  \
# Name
# Bulbasaur                 1     Grass  Poison   45      49       49       65
# Ivysaur                   2     Grass  Poison   60      62       63       80
# Venusaur                  3     Grass  Poison   80      82       83      100
# Mega Venusaur             4     Grass  Poison   80     100      123      122
# Charmander                5      Fire     NaN   39      52       43       60
# Charmeleon                6      Fire     NaN   58      64       58       80
# Charizard                 7      Fire  Flying   78      84       78      109
# Mega Charizard X          8      Fire  Dragon   78     130      111      130
# Mega Charizard Y          9      Fire  Flying   78     104       78      159
# Squirtle                 10     Water     NaN   44      48       65       50
# Wartortle                11     Water     NaN   59      63       80       65
# ...

# %%
df.query("Type_2  in ['Dark','Ghost']")
# Out:
#                           #    Type_1 Type_2   HP  Attack  Defense  Sp._Atk  \
# Name
# Mega Gyarados           142     Water   Dark   95     155      109       70
# Tyranitar               268      Rock   Dark  100     134      110       95
# Mega Tyranitar          269      Rock   Dark  100     164      150       95
# Nuzleaf                 298     Grass   Dark   70      70       40       60
# Shiftry                 299     Grass   Dark   90     100       60       90
# Shedinja                317       Bug  Ghost    1      90       45       30
# Sableye                 327      Dark  Ghost   50      75       75       65
# Mega Sableye            328      Dark  Ghost   50      85      125       85
# Carvanha                348     Water   Dark   45      90       20       65
# Sharpedo                349     Water   Dark   70     120       40       95
# Mega Sharpedo           350     Water   Dark   70     140       70      110
# ...

# %%
u=df["HP"]>46
df[u]
# Out:
#                           #    Type_1  Type_2   HP  Attack  Defense  Sp._Atk  \
# Name
# Ivysaur                   2     Grass  Poison   60      62       63       80
# Venusaur                  3     Grass  Poison   80      82       83      100
# Mega Venusaur             4     Grass  Poison   80     100      123      122
# Charmeleon                6      Fire     NaN   58      64       58       80
# Charizard                 7      Fire  Flying   78      84       78      109
# Mega Charizard X          8      Fire  Dragon   78     130      111      130
# Mega Charizard Y          9      Fire  Flying   78     104       78      159
# Wartortle                11     Water     NaN   59      63       80       65
# Blastoise                12     Water     NaN   79      83      100       85
# Mega Blastoise           13     Water     NaN   79     103      120      135
# Metapod                  15       Bug     NaN   50      20       55       25
# ...

# %%
df.query("HP>47")
# Out:
#                           #    Type_1  Type_2   HP  Attack  Defense  Sp._Atk  \
# Name
# Ivysaur                   2     Grass  Poison   60      62       63       80
# Venusaur                  3     Grass  Poison   80      82       83      100
# Mega Venusaur             4     Grass  Poison   80     100      123      122
# Charmeleon                6      Fire     NaN   58      64       58       80
# Charizard                 7      Fire  Flying   78      84       78      109
# Mega Charizard X          8      Fire  Dragon   78     130      111      130
# Mega Charizard Y          9      Fire  Flying   78     104       78      159
# Wartortle                11     Water     NaN   59      63       80       65
# Blastoise                12     Water     NaN   79      83      100       85
# Mega Blastoise           13     Water     NaN   79     103      120      135
# Metapod                  15       Bug     NaN   50      20       55       25
# ...
